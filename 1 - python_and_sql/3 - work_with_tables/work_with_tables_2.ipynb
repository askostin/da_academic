# %% [markdown]
# # Работа с таблицами (упражнения) - настройка стиля

# %% [markdown]
# - ```df.style.highlight_null()``` – подсветить ячейки с пропущенными значениями
# - ```df.style.highlight_max()``` – подсветить ячейки с максимальными значениями по колонкам
# - ```df.style.highlight_min()``` – подсветить ячейки с минимальными значениями по колонкам
# - ```df.style.applymap(func)``` – применить стилевую функцию к каждой ячейке датафрэйма
# - ```df.style.apply(func, axis, subset)``` – применить стилевую функцию к каждой колонке/строке в зависимости от axis, subset позволяет выбрать часть колонок для оформления
# - ```render()``` – после декорирования возвращает HTML, описывающий табличку

# %% [markdown]
# ## Загрузка библиотек и настройка среды

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Индексы и подписи

# %%
np.random.seed(77)
df = pd.DataFrame({'A': list(range(5)), 
                   'B': np.random.randint(0, 10, 5),
                   'C': np.random.randint(-10, 10, 5), 
                   'D': np.random.randint(-10, 100, 5)})
df
# Out:
#    A  B   C   D
# 0  0  7 -10  49
# 1  1  4  -3  90
# 2  2  4   2  44
# 3  3  5   9  26
# 4  4  8 -10  37

# %%
df.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_c4340_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c4340_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_c4340_row0_col1" class="data row0 col1" >7</td>
#       <td id="T_c4340_row0_col2" class="data row0 col2" >-10</td>
#       <td id="T_c4340_row0_col3" class="data row0 col3" >49</td>
#     </tr>
#     <tr>
#       <td id="T_c4340_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_c4340_row1_col1" class="data row1 col1" >4</td>
#       <td id="T_c4340_row1_col2" class="data row1 col2" >-3</td>
#       <td id="T_c4340_row1_col3" class="data row1 col3" >90</td>
#     </tr>
#     <tr>
#       <td id="T_c4340_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_c4340_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_c4340_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_c4340_row2_col3" class="data row2 col3" >44</td>
#     </tr>
#     <tr>
#       <td id="T_c4340_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_c4340_row3_col1" class="data row3 col1" >5</td>
#       <td id="T_c4340_row3_col2" class="data row3 col2" >9</td>
#       <td id="T_c4340_row3_col3" class="data row3 col3" >26</td>
#     </tr>
#     <tr>
#       <td id="T_c4340_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_c4340_row4_col1" class="data row4 col1" >8</td>
#       <td id="T_c4340_row4_col2" class="data row4 col2" >-10</td>
#       <td id="T_c4340_row4_col3" class="data row4 col3" >37</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.style.hide_index().set_caption('Cool table')
# Out:
# <style type="text/css">
# </style>
# <table id="T_ea1bb_">
#   <caption>Cool table</caption>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ea1bb_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_ea1bb_row0_col1" class="data row0 col1" >7</td>
#       <td id="T_ea1bb_row0_col2" class="data row0 col2" >-10</td>
#       <td id="T_ea1bb_row0_col3" class="data row0 col3" >49</td>
#     </tr>
#     <tr>
#       <td id="T_ea1bb_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_ea1bb_row1_col1" class="data row1 col1" >4</td>
#       <td id="T_ea1bb_row1_col2" class="data row1 col2" >-3</td>
#       <td id="T_ea1bb_row1_col3" class="data row1 col3" >90</td>
#     </tr>
#     <tr>
#       <td id="T_ea1bb_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_ea1bb_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_ea1bb_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_ea1bb_row2_col3" class="data row2 col3" >44</td>
#     </tr>
#     <tr>
#       <td id="T_ea1bb_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_ea1bb_row3_col1" class="data row3 col1" >5</td>
#       <td id="T_ea1bb_row3_col2" class="data row3 col2" >9</td>
#       <td id="T_ea1bb_row3_col3" class="data row3 col3" >26</td>
#     </tr>
#     <tr>
#       <td id="T_ea1bb_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_ea1bb_row4_col1" class="data row4 col1" >8</td>
#       <td id="T_ea1bb_row4_col2" class="data row4 col2" >-10</td>
#       <td id="T_ea1bb_row4_col3" class="data row4 col3" >37</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Раскрашиваем ячейки

# %%
df.style.highlight_max(axis = 1)
# Out:
# <style type="text/css">
# #T_81412_row0_col3, #T_81412_row1_col3, #T_81412_row2_col3, #T_81412_row3_col3, #T_81412_row4_col3 {
#   background-color: yellow;
# }
# </style>
# <table id="T_81412_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_81412_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_81412_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_81412_row0_col1" class="data row0 col1" >7</td>
#       <td id="T_81412_row0_col2" class="data row0 col2" >-10</td>
#       <td id="T_81412_row0_col3" class="data row0 col3" >49</td>
#     </tr>
#     <tr>
#       <th id="T_81412_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_81412_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_81412_row1_col1" class="data row1 col1" >4</td>
#       <td id="T_81412_row1_col2" class="data row1 col2" >-3</td>
#       <td id="T_81412_row1_col3" class="data row1 col3" >90</td>
#     </tr>
#     <tr>
#       <th id="T_81412_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_81412_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_81412_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_81412_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_81412_row2_col3" class="data row2 col3" >44</td>
#     </tr>
#     <tr>
#       <th id="T_81412_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_81412_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_81412_row3_col1" class="data row3 col1" >5</td>
#       <td id="T_81412_row3_col2" class="data row3 col2" >9</td>
#       <td id="T_81412_row3_col3" class="data row3 col3" >26</td>
#     </tr>
#     <tr>
#       <th id="T_81412_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_81412_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_81412_row4_col1" class="data row4 col1" >8</td>
#       <td id="T_81412_row4_col2" class="data row4 col2" >-10</td>
#       <td id="T_81412_row4_col3" class="data row4 col3" >37</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.style.highlight_max(axis = 'index')
# Out:
# <style type="text/css">
# #T_2d742_row1_col3, #T_2d742_row3_col2, #T_2d742_row4_col0, #T_2d742_row4_col1 {
#   background-color: yellow;
# }
# </style>
# <table id="T_2d742_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2d742_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2d742_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_2d742_row0_col1" class="data row0 col1" >7</td>
#       <td id="T_2d742_row0_col2" class="data row0 col2" >-10</td>
#       <td id="T_2d742_row0_col3" class="data row0 col3" >49</td>
#     </tr>
#     <tr>
#       <th id="T_2d742_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2d742_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_2d742_row1_col1" class="data row1 col1" >4</td>
#       <td id="T_2d742_row1_col2" class="data row1 col2" >-3</td>
#       <td id="T_2d742_row1_col3" class="data row1 col3" >90</td>
#     </tr>
#     <tr>
#       <th id="T_2d742_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2d742_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_2d742_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_2d742_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_2d742_row2_col3" class="data row2 col3" >44</td>
#     </tr>
#     <tr>
#       <th id="T_2d742_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2d742_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_2d742_row3_col1" class="data row3 col1" >5</td>
#       <td id="T_2d742_row3_col2" class="data row3 col2" >9</td>
#       <td id="T_2d742_row3_col3" class="data row3 col3" >26</td>
#     </tr>
#     <tr>
#       <th id="T_2d742_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2d742_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_2d742_row4_col1" class="data row4 col1" >8</td>
#       <td id="T_2d742_row4_col2" class="data row4 col2" >-10</td>
#       <td id="T_2d742_row4_col3" class="data row4 col3" >37</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.style.highlight_min()
# Out:
# <style type="text/css">
# #T_d2cab_row0_col0, #T_d2cab_row0_col2, #T_d2cab_row1_col1, #T_d2cab_row2_col1, #T_d2cab_row3_col3, #T_d2cab_row4_col2 {
#   background-color: yellow;
# }
# </style>
# <table id="T_d2cab_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2cab_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d2cab_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_d2cab_row0_col1" class="data row0 col1" >7</td>
#       <td id="T_d2cab_row0_col2" class="data row0 col2" >-10</td>
#       <td id="T_d2cab_row0_col3" class="data row0 col3" >49</td>
#     </tr>
#     <tr>
#       <th id="T_d2cab_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d2cab_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_d2cab_row1_col1" class="data row1 col1" >4</td>
#       <td id="T_d2cab_row1_col2" class="data row1 col2" >-3</td>
#       <td id="T_d2cab_row1_col3" class="data row1 col3" >90</td>
#     </tr>
#     <tr>
#       <th id="T_d2cab_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d2cab_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_d2cab_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_d2cab_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_d2cab_row2_col3" class="data row2 col3" >44</td>
#     </tr>
#     <tr>
#       <th id="T_d2cab_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d2cab_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_d2cab_row3_col1" class="data row3 col1" >5</td>
#       <td id="T_d2cab_row3_col2" class="data row3 col2" >9</td>
#       <td id="T_d2cab_row3_col3" class="data row3 col3" >26</td>
#     </tr>
#     <tr>
#       <th id="T_d2cab_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d2cab_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_d2cab_row4_col1" class="data row4 col1" >8</td>
#       <td id="T_d2cab_row4_col2" class="data row4 col2" >-10</td>
#       <td id="T_d2cab_row4_col3" class="data row4 col3" >37</td>
#     </tr>
#   </tbody>
# </table>

# %%
(df.style
 .highlight_min('A', color='red')
 .highlight_max('B', color='orange')
 .background_gradient(subset=['C','D'],cmap='viridis')
)
# Out:
# <style type="text/css">
# #T_569f2_row0_col0 {
#   background-color: red;
# }
# #T_569f2_row0_col2, #T_569f2_row3_col3, #T_569f2_row4_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_569f2_row0_col3 {
#   background-color: #2e6f8e;
#   color: #f1f1f1;
# }
# #T_569f2_row1_col2 {
#   background-color: #2d718e;
#   color: #f1f1f1;
# }
# #T_569f2_row1_col3, #T_569f2_row3_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_569f2_row2_col2 {
#   background-color: #29af7f;
#   color: #f1f1f1;
# }
# #T_569f2_row2_col3 {
#   background-color: #375b8d;
#   color: #f1f1f1;
# }
# #T_569f2_row4_col1 {
#   background-color: orange;
# }
# #T_569f2_row4_col3 {
#   background-color: #443b84;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_569f2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_569f2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_569f2_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_569f2_row0_col1" class="data row0 col1" >7</td>
#       <td id="T_569f2_row0_col2" class="data row0 col2" >-10</td>
#       <td id="T_569f2_row0_col3" class="data row0 col3" >49</td>
#     </tr>
#     <tr>
#       <th id="T_569f2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_569f2_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_569f2_row1_col1" class="data row1 col1" >4</td>
#       <td id="T_569f2_row1_col2" class="data row1 col2" >-3</td>
#       <td id="T_569f2_row1_col3" class="data row1 col3" >90</td>
#     </tr>
#     <tr>
#       <th id="T_569f2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_569f2_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_569f2_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_569f2_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_569f2_row2_col3" class="data row2 col3" >44</td>
#     </tr>
#     <tr>
#       <th id="T_569f2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_569f2_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_569f2_row3_col1" class="data row3 col1" >5</td>
#       <td id="T_569f2_row3_col2" class="data row3 col2" >9</td>
#       <td id="T_569f2_row3_col3" class="data row3 col3" >26</td>
#     </tr>
#     <tr>
#       <th id="T_569f2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_569f2_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_569f2_row4_col1" class="data row4 col1" >8</td>
#       <td id="T_569f2_row4_col2" class="data row4 col2" >-10</td>
#       <td id="T_569f2_row4_col3" class="data row4 col3" >37</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.style.bar(subset=['C', 'D'], color='#67A5EB')
# Out:
# <style type="text/css">
# #T_945d9_row0_col2, #T_945d9_row3_col3, #T_945d9_row4_col2 {
#   width: 10em;
#   height: 80%;
# }
# #T_945d9_row0_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#67A5EB 35.9%, transparent 35.9%);
# }
# #T_945d9_row1_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#67A5EB 36.8%, transparent 36.8%);
# }
# #T_945d9_row1_col3, #T_945d9_row3_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#67A5EB 100.0%, transparent 100.0%);
# }
# #T_945d9_row2_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#67A5EB 63.2%, transparent 63.2%);
# }
# #T_945d9_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#67A5EB 28.1%, transparent 28.1%);
# }
# #T_945d9_row4_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#67A5EB 17.2%, transparent 17.2%);
# }
# </style>
# <table id="T_945d9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_945d9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_945d9_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_945d9_row0_col1" class="data row0 col1" >7</td>
#       <td id="T_945d9_row0_col2" class="data row0 col2" >-10</td>
#       <td id="T_945d9_row0_col3" class="data row0 col3" >49</td>
#     </tr>
#     <tr>
#       <th id="T_945d9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_945d9_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_945d9_row1_col1" class="data row1 col1" >4</td>
#       <td id="T_945d9_row1_col2" class="data row1 col2" >-3</td>
#       <td id="T_945d9_row1_col3" class="data row1 col3" >90</td>
#     </tr>
#     <tr>
#       <th id="T_945d9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_945d9_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_945d9_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_945d9_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_945d9_row2_col3" class="data row2 col3" >44</td>
#     </tr>
#     <tr>
#       <th id="T_945d9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_945d9_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_945d9_row3_col1" class="data row3 col1" >5</td>
#       <td id="T_945d9_row3_col2" class="data row3 col2" >9</td>
#       <td id="T_945d9_row3_col3" class="data row3 col3" >26</td>
#     </tr>
#     <tr>
#       <th id="T_945d9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_945d9_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_945d9_row4_col1" class="data row4 col1" >8</td>
#       <td id="T_945d9_row4_col2" class="data row4 col2" >-10</td>
#       <td id="T_945d9_row4_col3" class="data row4 col3" >37</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.style.bar(subset=['C', 'D'], color='#67A5EB', align='mid')
# Out:
# <style type="text/css">
# #T_b913c_row0_col2, #T_b913c_row4_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#67A5EB 52.6%, transparent 52.6%);
# }
# #T_b913c_row0_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#67A5EB 54.4%, transparent 54.4%);
# }
# #T_b913c_row1_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 36.8%, #67A5EB 36.8%, #67A5EB 52.6%, transparent 52.6%);
# }
# #T_b913c_row1_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#67A5EB 100.0%, transparent 100.0%);
# }
# #T_b913c_row2_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 52.6%, #67A5EB 52.6%, #67A5EB 63.2%, transparent 63.2%);
# }
# #T_b913c_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#67A5EB 48.9%, transparent 48.9%);
# }
# #T_b913c_row3_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 52.6%, #67A5EB 52.6%, #67A5EB 100.0%, transparent 100.0%);
# }
# #T_b913c_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#67A5EB 28.9%, transparent 28.9%);
# }
# #T_b913c_row4_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#67A5EB 41.1%, transparent 41.1%);
# }
# </style>
# <table id="T_b913c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b913c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b913c_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_b913c_row0_col1" class="data row0 col1" >7</td>
#       <td id="T_b913c_row0_col2" class="data row0 col2" >-10</td>
#       <td id="T_b913c_row0_col3" class="data row0 col3" >49</td>
#     </tr>
#     <tr>
#       <th id="T_b913c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b913c_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_b913c_row1_col1" class="data row1 col1" >4</td>
#       <td id="T_b913c_row1_col2" class="data row1 col2" >-3</td>
#       <td id="T_b913c_row1_col3" class="data row1 col3" >90</td>
#     </tr>
#     <tr>
#       <th id="T_b913c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b913c_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_b913c_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_b913c_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_b913c_row2_col3" class="data row2 col3" >44</td>
#     </tr>
#     <tr>
#       <th id="T_b913c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b913c_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_b913c_row3_col1" class="data row3 col1" >5</td>
#       <td id="T_b913c_row3_col2" class="data row3 col2" >9</td>
#       <td id="T_b913c_row3_col3" class="data row3 col3" >26</td>
#     </tr>
#     <tr>
#       <th id="T_b913c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b913c_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_b913c_row4_col1" class="data row4 col1" >8</td>
#       <td id="T_b913c_row4_col2" class="data row4 col2" >-10</td>
#       <td id="T_b913c_row4_col3" class="data row4 col3" >37</td>
#     </tr>
#   </tbody>
# </table>

# %%
(df
 .style
 .hide_index()
 .bar(subset=['C'], align='mid',color=['#d65f5f', '#5fba7d'])
)
# Out:
# <style type="text/css">
# #T_4ba36_row0_col2, #T_4ba36_row4_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 52.6%, transparent 52.6%);
# }
# #T_4ba36_row1_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 36.8%, #d65f5f 36.8%, #d65f5f 52.6%, transparent 52.6%);
# }
# #T_4ba36_row2_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 52.6%, #5fba7d 52.6%, #5fba7d 63.2%, transparent 63.2%);
# }
# #T_4ba36_row3_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 52.6%, #5fba7d 52.6%, #5fba7d 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_4ba36_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4ba36_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_4ba36_row0_col1" class="data row0 col1" >7</td>
#       <td id="T_4ba36_row0_col2" class="data row0 col2" >-10</td>
#       <td id="T_4ba36_row0_col3" class="data row0 col3" >49</td>
#     </tr>
#     <tr>
#       <td id="T_4ba36_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_4ba36_row1_col1" class="data row1 col1" >4</td>
#       <td id="T_4ba36_row1_col2" class="data row1 col2" >-3</td>
#       <td id="T_4ba36_row1_col3" class="data row1 col3" >90</td>
#     </tr>
#     <tr>
#       <td id="T_4ba36_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_4ba36_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_4ba36_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_4ba36_row2_col3" class="data row2 col3" >44</td>
#     </tr>
#     <tr>
#       <td id="T_4ba36_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_4ba36_row3_col1" class="data row3 col1" >5</td>
#       <td id="T_4ba36_row3_col2" class="data row3 col2" >9</td>
#       <td id="T_4ba36_row3_col3" class="data row3 col3" >26</td>
#     </tr>
#     <tr>
#       <td id="T_4ba36_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_4ba36_row4_col1" class="data row4 col1" >8</td>
#       <td id="T_4ba36_row4_col2" class="data row4 col2" >-10</td>
#       <td id="T_4ba36_row4_col3" class="data row4 col3" >37</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Форматирование отображения чисел

# %%
df = pd.DataFrame({'A': np.linspace(1, 10, 5)})
df = pd.concat([df, pd.DataFrame(np.random.randn(5, 4), columns=list('BCDE'))],axis=1)
df['F'] = np.random.choice(['A', 'B'], size=5)
df.iloc[3, 3] = np.nan 
df.iloc[0, 2] = np.nan 
df
# Out:
#        A         B         C         D         E  F
# 0   1.00  0.797939       NaN -1.652119  0.717119  B
# 1   3.25  0.977228 -1.040849 -0.643520 -0.112520  A
# 2   5.50 -0.314166  1.627440 -0.361227 -0.173046  B
# 3   7.75 -1.951309 -0.978210       NaN -1.178379  A
# 4  10.00 -0.515551 -0.063015 -0.559371  0.796697  A

# %%
df.style.format("{:+.2f}", subset=df.columns.drop('F'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_6a28c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#       <th class="col_heading level0 col4" >E</th>
#       <th class="col_heading level0 col5" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a28c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6a28c_row0_col0" class="data row0 col0" >+1.00</td>
#       <td id="T_6a28c_row0_col1" class="data row0 col1" >+0.80</td>
#       <td id="T_6a28c_row0_col2" class="data row0 col2" >+nan</td>
#       <td id="T_6a28c_row0_col3" class="data row0 col3" >-1.65</td>
#       <td id="T_6a28c_row0_col4" class="data row0 col4" >+0.72</td>
#       <td id="T_6a28c_row0_col5" class="data row0 col5" >B</td>
#     </tr>
#     <tr>
#       <th id="T_6a28c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6a28c_row1_col0" class="data row1 col0" >+3.25</td>
#       <td id="T_6a28c_row1_col1" class="data row1 col1" >+0.98</td>
#       <td id="T_6a28c_row1_col2" class="data row1 col2" >-1.04</td>
#       <td id="T_6a28c_row1_col3" class="data row1 col3" >-0.64</td>
#       <td id="T_6a28c_row1_col4" class="data row1 col4" >-0.11</td>
#       <td id="T_6a28c_row1_col5" class="data row1 col5" >A</td>
#     </tr>
#     <tr>
#       <th id="T_6a28c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6a28c_row2_col0" class="data row2 col0" >+5.50</td>
#       <td id="T_6a28c_row2_col1" class="data row2 col1" >-0.31</td>
#       <td id="T_6a28c_row2_col2" class="data row2 col2" >+1.63</td>
#       <td id="T_6a28c_row2_col3" class="data row2 col3" >-0.36</td>
#       <td id="T_6a28c_row2_col4" class="data row2 col4" >-0.17</td>
#       <td id="T_6a28c_row2_col5" class="data row2 col5" >B</td>
#     </tr>
#     <tr>
#       <th id="T_6a28c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6a28c_row3_col0" class="data row3 col0" >+7.75</td>
#       <td id="T_6a28c_row3_col1" class="data row3 col1" >-1.95</td>
#       <td id="T_6a28c_row3_col2" class="data row3 col2" >-0.98</td>
#       <td id="T_6a28c_row3_col3" class="data row3 col3" >+nan</td>
#       <td id="T_6a28c_row3_col4" class="data row3 col4" >-1.18</td>
#       <td id="T_6a28c_row3_col5" class="data row3 col5" >A</td>
#     </tr>
#     <tr>
#       <th id="T_6a28c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6a28c_row4_col0" class="data row4 col0" >+10.00</td>
#       <td id="T_6a28c_row4_col1" class="data row4 col1" >-0.52</td>
#       <td id="T_6a28c_row4_col2" class="data row4 col2" >-0.06</td>
#       <td id="T_6a28c_row4_col3" class="data row4 col3" >-0.56</td>
#       <td id="T_6a28c_row4_col4" class="data row4 col4" >+0.80</td>
#       <td id="T_6a28c_row4_col5" class="data row4 col5" >A</td>
#     </tr>
#   </tbody>
# </table>

# %%
(df.style
 .format({'B': "{:0<4.0f}", 'D': '{:+.2f}'})
 .hide_index()
 .set_caption('Новая таблица'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_67147_">
#   <caption>Новая таблица</caption>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >A</th>
#       <th class="col_heading level0 col1" >B</th>
#       <th class="col_heading level0 col2" >C</th>
#       <th class="col_heading level0 col3" >D</th>
#       <th class="col_heading level0 col4" >E</th>
#       <th class="col_heading level0 col5" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_67147_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_67147_row0_col1" class="data row0 col1" >1000</td>
#       <td id="T_67147_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_67147_row0_col3" class="data row0 col3" >-1.65</td>
#       <td id="T_67147_row0_col4" class="data row0 col4" >0.717119</td>
#       <td id="T_67147_row0_col5" class="data row0 col5" >B</td>
#     </tr>
#     <tr>
#       <td id="T_67147_row1_col0" class="data row1 col0" >3.250000</td>
#       <td id="T_67147_row1_col1" class="data row1 col1" >1000</td>
#       <td id="T_67147_row1_col2" class="data row1 col2" >-1.040849</td>
#       <td id="T_67147_row1_col3" class="data row1 col3" >-0.64</td>
#       <td id="T_67147_row1_col4" class="data row1 col4" >-0.112520</td>
#       <td id="T_67147_row1_col5" class="data row1 col5" >A</td>
#     </tr>
#     <tr>
#       <td id="T_67147_row2_col0" class="data row2 col0" >5.500000</td>
#       <td id="T_67147_row2_col1" class="data row2 col1" >-000</td>
#       <td id="T_67147_row2_col2" class="data row2 col2" >1.627440</td>
#       <td id="T_67147_row2_col3" class="data row2 col3" >-0.36</td>
#       <td id="T_67147_row2_col4" class="data row2 col4" >-0.173046</td>
#       <td id="T_67147_row2_col5" class="data row2 col5" >B</td>
#     </tr>
#     <tr>
#       <td id="T_67147_row3_col0" class="data row3 col0" >7.750000</td>
#       <td id="T_67147_row3_col1" class="data row3 col1" >-200</td>
#       <td id="T_67147_row3_col2" class="data row3 col2" >-0.978210</td>
#       <td id="T_67147_row3_col3" class="data row3 col3" >+nan</td>
#       <td id="T_67147_row3_col4" class="data row3 col4" >-1.178379</td>
#       <td id="T_67147_row3_col5" class="data row3 col5" >A</td>
#     </tr>
#     <tr>
#       <td id="T_67147_row4_col0" class="data row4 col0" >10.000000</td>
#       <td id="T_67147_row4_col1" class="data row4 col1" >-100</td>
#       <td id="T_67147_row4_col2" class="data row4 col2" >-0.063015</td>
#       <td id="T_67147_row4_col3" class="data row4 col3" >-0.56</td>
#       <td id="T_67147_row4_col4" class="data row4 col4" >0.796697</td>
#       <td id="T_67147_row4_col5" class="data row4 col5" >A</td>
#     </tr>
#   </tbody>
# </table>

# %%
(df.style
 .bar(align='mid', color=['#d65f5f', '#5fba7d'])
 .to_excel('styled.xlsx', engine='openpyxl')
)

# %% [markdown]
# ## Retention
#
# **Retention** – показатель удержания пользователей. Иными словами – отражает то, сколько пользователей возвращаются в продукт спустя заданное время.
#
# Обычно день начала использования сервиса называется **Day 0** – момент, когда юзер впервые воспользовался продуктом. **N-Day Retention** показывает, сколько процентов пользователей, начавших пользоваться продуктом в день 0, вернулись и продолжили использовать продукт N дней спустя.

# %%
user_retention = \
    pd.read_csv("https://stepik.org/media/attachments/lesson/367416/user_retention.csv",
                index_col = 0)

# %%
user_retention
# Out:
#            0         1         2         3         4         5         6  \
# Cohort
# 2010-12  1.0  0.381857  0.334388  0.387131  0.359705  0.396624  0.379747
# 2011-01  1.0  0.239905  0.282660  0.242280  0.327791  0.299287  0.261283
# 2011-02  1.0  0.247368  0.192105  0.278947  0.268421  0.247368  0.255263
# 2011-03  1.0  0.190909  0.254545  0.218182  0.231818  0.177273  0.263636
# 2011-04  1.0  0.227425  0.220736  0.210702  0.207358  0.237458  0.230769
# 2011-05  1.0  0.236559  0.172043  0.172043  0.215054  0.243728  0.265233
# 2011-06  1.0  0.208511  0.187234  0.272340  0.246809  0.336170  0.102128
# 2011-07  1.0  0.209424  0.204188  0.230366  0.272251  0.115183       NaN
# 2011-08  1.0  0.251497  0.251497  0.251497  0.137725       NaN       NaN
# 2011-09  1.0  0.298658  0.325503  0.120805       NaN       NaN       NaN
# 2011-10  1.0  0.264205  0.130682       NaN       NaN       NaN       NaN
# 2011-11  1.0  0.134375       NaN       NaN       NaN       NaN       NaN
# 2011-12  1.0       NaN       NaN       NaN       NaN       NaN       NaN
#
#                 7         8         9        10        11        12
# Cohort
# 2010-12  0.354430  0.354430  0.394515  0.373418  0.500000  0.274262
# 2011-01  0.256532  0.311164  0.346793  0.368171  0.149644       NaN
# 2011-02  0.281579  0.257895  0.313158  0.092105       NaN       NaN
# 2011-03  0.238636  0.288636  0.088636       NaN       NaN       NaN
# 2011-04  0.260870  0.083612       NaN       NaN       NaN       NaN
# 2011-05  0.103943       NaN       NaN       NaN       NaN       NaN
# 2011-06       NaN       NaN       NaN       NaN       NaN       NaN
# 2011-07       NaN       NaN       NaN       NaN       NaN       NaN
# 2011-08       NaN       NaN       NaN       NaN       NaN       NaN
# 2011-09       NaN       NaN       NaN       NaN       NaN       NaN
# 2011-10       NaN       NaN       NaN       NaN       NaN       NaN
# 2011-11       NaN       NaN       NaN       NaN       NaN       NaN
# 2011-12       NaN       NaN       NaN       NaN       NaN       NaN

# %%
ur_style = (user_retention
            .style
            .set_caption('User retention by cohort')  # добавляем подпись
            .background_gradient(cmap='viridis')  # раскрашиваем ячейки по столбцам
            .highlight_null('white')  # делаем белый фон для значений NaN
            .format("{:.2%}", na_rep=""))  # числа форматируем как проценты, NaN заменяем на пустоту
ur_style
# Out:
# <style type="text/css">
# #T_42797_row0_col0, #T_42797_row0_col12, #T_42797_row1_col0, #T_42797_row1_col11, #T_42797_row2_col0, #T_42797_row2_col10, #T_42797_row3_col0, #T_42797_row3_col9, #T_42797_row4_col0, #T_42797_row4_col8, #T_42797_row5_col0, #T_42797_row5_col7, #T_42797_row6_col0, #T_42797_row6_col6, #T_42797_row7_col0, #T_42797_row7_col5, #T_42797_row8_col0, #T_42797_row8_col4, #T_42797_row9_col0, #T_42797_row9_col3, #T_42797_row10_col0, #T_42797_row10_col2, #T_42797_row11_col0, #T_42797_row11_col1, #T_42797_row12_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_42797_row0_col1, #T_42797_row0_col2, #T_42797_row0_col3, #T_42797_row0_col4, #T_42797_row0_col5, #T_42797_row0_col6, #T_42797_row0_col7, #T_42797_row0_col8, #T_42797_row0_col9, #T_42797_row0_col10, #T_42797_row0_col11 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_42797_row1_col1 {
#   background-color: #277f8e;
#   color: #f1f1f1;
# }
# #T_42797_row1_col2 {
#   background-color: #5ac864;
#   color: #000000;
# }
# #T_42797_row1_col3, #T_42797_row2_col1, #T_42797_row5_col5 {
#   background-color: #25858e;
#   color: #f1f1f1;
# }
# #T_42797_row1_col4 {
#   background-color: #a0da39;
#   color: #000000;
# }
# #T_42797_row1_col5 {
#   background-color: #31b57b;
#   color: #f1f1f1;
# }
# #T_42797_row1_col6 {
#   background-color: #1fa187;
#   color: #f1f1f1;
# }
# #T_42797_row1_col7, #T_42797_row3_col2, #T_42797_row7_col4 {
#   background-color: #24aa83;
#   color: #f1f1f1;
# }
# #T_42797_row1_col8 {
#   background-color: #95d840;
#   color: #000000;
# }
# #T_42797_row1_col9 {
#   background-color: #98d83e;
#   color: #000000;
# }
# #T_42797_row1_col10 {
#   background-color: #f4e61e;
#   color: #000000;
# }
# #T_42797_row1_col12, #T_42797_row2_col12, #T_42797_row3_col12, #T_42797_row4_col12, #T_42797_row5_col12, #T_42797_row6_col12, #T_42797_row7_col12, #T_42797_row8_col12, #T_42797_row9_col12, #T_42797_row10_col12, #T_42797_row11_col12, #T_42797_row12_col12 {
#   background-color: #440154;
#   color: #f1f1f1;
#   background-color: white;
# }
# #T_42797_row2_col2, #T_42797_row7_col1 {
#   background-color: #34608d;
#   color: #f1f1f1;
# }
# #T_42797_row2_col3 {
#   background-color: #22a785;
#   color: #f1f1f1;
# }
# #T_42797_row2_col4, #T_42797_row5_col6 {
#   background-color: #21a585;
#   color: #f1f1f1;
# }
# #T_42797_row2_col5 {
#   background-color: #23898e;
#   color: #f1f1f1;
# }
# #T_42797_row2_col6 {
#   background-color: #1e9d89;
#   color: #f1f1f1;
# }
# #T_42797_row2_col7 {
#   background-color: #48c16e;
#   color: #f1f1f1;
# }
# #T_42797_row2_col8 {
#   background-color: #2db27d;
#   color: #f1f1f1;
# }
# #T_42797_row2_col9 {
#   background-color: #54c568;
#   color: #000000;
# }
# #T_42797_row2_col11, #T_42797_row3_col10, #T_42797_row3_col11, #T_42797_row4_col9, #T_42797_row4_col10, #T_42797_row4_col11, #T_42797_row5_col8, #T_42797_row5_col9, #T_42797_row5_col10, #T_42797_row5_col11, #T_42797_row6_col7, #T_42797_row6_col8, #T_42797_row6_col9, #T_42797_row6_col10, #T_42797_row6_col11, #T_42797_row7_col6, #T_42797_row7_col7, #T_42797_row7_col8, #T_42797_row7_col9, #T_42797_row7_col10, #T_42797_row7_col11, #T_42797_row8_col5, #T_42797_row8_col6, #T_42797_row8_col7, #T_42797_row8_col8, #T_42797_row8_col9, #T_42797_row8_col10, #T_42797_row8_col11, #T_42797_row9_col4, #T_42797_row9_col5, #T_42797_row9_col6, #T_42797_row9_col7, #T_42797_row9_col8, #T_42797_row9_col9, #T_42797_row9_col10, #T_42797_row9_col11, #T_42797_row10_col3, #T_42797_row10_col4, #T_42797_row10_col5, #T_42797_row10_col6, #T_42797_row10_col7, #T_42797_row10_col8, #T_42797_row10_col9, #T_42797_row10_col10, #T_42797_row10_col11, #T_42797_row11_col2, #T_42797_row11_col3, #T_42797_row11_col4, #T_42797_row11_col5, #T_42797_row11_col6, #T_42797_row11_col7, #T_42797_row11_col8, #T_42797_row11_col9, #T_42797_row11_col10, #T_42797_row11_col11, #T_42797_row12_col1, #T_42797_row12_col2, #T_42797_row12_col3, #T_42797_row12_col4, #T_42797_row12_col5, #T_42797_row12_col6, #T_42797_row12_col7, #T_42797_row12_col8, #T_42797_row12_col9, #T_42797_row12_col10, #T_42797_row12_col11 {
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: white;
# }
# #T_42797_row3_col1 {
#   background-color: #3e4c8a;
#   color: #f1f1f1;
# }
# #T_42797_row3_col3 {
#   background-color: #2d708e;
#   color: #f1f1f1;
# }
# #T_42797_row3_col4 {
#   background-color: #277e8e;
#   color: #f1f1f1;
# }
# #T_42797_row3_col5 {
#   background-color: #3e4989;
#   color: #f1f1f1;
# }
# #T_42797_row3_col6 {
#   background-color: #20a386;
#   color: #f1f1f1;
# }
# #T_42797_row3_col7 {
#   background-color: #1f998a;
#   color: #f1f1f1;
# }
# #T_42797_row3_col8 {
#   background-color: #60ca60;
#   color: #000000;
# }
# #T_42797_row4_col1 {
#   background-color: #2c728e;
#   color: #f1f1f1;
# }
# #T_42797_row4_col2 {
#   background-color: #26828e;
#   color: #f1f1f1;
# }
# #T_42797_row4_col3 {
#   background-color: #30698e;
#   color: #f1f1f1;
# }
# #T_42797_row4_col4 {
#   background-color: #33638d;
#   color: #f1f1f1;
# }
# #T_42797_row4_col5 {
#   background-color: #26818e;
#   color: #f1f1f1;
# }
# #T_42797_row4_col6 {
#   background-color: #24878e;
#   color: #f1f1f1;
# }
# #T_42797_row4_col7 {
#   background-color: #28ae80;
#   color: #f1f1f1;
# }
# #T_42797_row5_col1, #T_42797_row7_col3 {
#   background-color: #297b8e;
#   color: #f1f1f1;
# }
# #T_42797_row5_col2 {
#   background-color: #414487;
#   color: #f1f1f1;
# }
# #T_42797_row5_col3 {
#   background-color: #424186;
#   color: #f1f1f1;
# }
# #T_42797_row5_col4 {
#   background-color: #2f6c8e;
#   color: #f1f1f1;
# }
# #T_42797_row6_col1 {
#   background-color: #355f8d;
#   color: #f1f1f1;
# }
# #T_42797_row6_col2 {
#   background-color: #375a8c;
#   color: #f1f1f1;
# }
# #T_42797_row6_col3 {
#   background-color: #1fa188;
#   color: #f1f1f1;
# }
# #T_42797_row6_col4, #T_42797_row8_col3 {
#   background-color: #218e8d;
#   color: #f1f1f1;
# }
# #T_42797_row6_col5 {
#   background-color: #73d056;
#   color: #000000;
# }
# #T_42797_row7_col2 {
#   background-color: #2e6f8e;
#   color: #f1f1f1;
# }
# #T_42797_row8_col1 {
#   background-color: #238a8d;
#   color: #f1f1f1;
# }
# #T_42797_row8_col2 {
#   background-color: #21a685;
#   color: #f1f1f1;
# }
# #T_42797_row9_col1 {
#   background-color: #34b679;
#   color: #f1f1f1;
# }
# #T_42797_row9_col2 {
#   background-color: #e2e418;
#   color: #000000;
# }
# #T_42797_row10_col1 {
#   background-color: #1f968b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_42797_">
#   <caption>User retention by cohort</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >4</th>
#       <th class="col_heading level0 col5" >5</th>
#       <th class="col_heading level0 col6" >6</th>
#       <th class="col_heading level0 col7" >7</th>
#       <th class="col_heading level0 col8" >8</th>
#       <th class="col_heading level0 col9" >9</th>
#       <th class="col_heading level0 col10" >10</th>
#       <th class="col_heading level0 col11" >11</th>
#       <th class="col_heading level0 col12" >12</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Cohort</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42797_level0_row0" class="row_heading level0 row0" >2010-12</th>
#       <td id="T_42797_row0_col0" class="data row0 col0" >100.00%</td>
#       <td id="T_42797_row0_col1" class="data row0 col1" >38.19%</td>
#       <td id="T_42797_row0_col2" class="data row0 col2" >33.44%</td>
#       <td id="T_42797_row0_col3" class="data row0 col3" >38.71%</td>
#       <td id="T_42797_row0_col4" class="data row0 col4" >35.97%</td>
#       <td id="T_42797_row0_col5" c
